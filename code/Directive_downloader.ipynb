# %%
import re
import os
import requests
from bs4 import BeautifulSoup
import pandas as pd

# === CONFIGURATION ===
eurlex_url = 'https://eur-lex.europa.eu/legal-content/EN/NIM/?uri=CELEX:32003L0096'  # CHANGE THIS!

ammend = False  # Set to True if the directive is an amendment

output_dir = '/Users/nicolomarchini/Documents/Università/Magistrale/Tesi Magistrale/Directives'   

# === UTILITY FUNCTIONS ===
def standardize_date(date_str):
    if not date_str: return ""
    date_str = date_str.strip()
    match = re.match(r"^(\d{2})/(\d{2})/(\d{4})$", date_str)
    if match:
        day, month, year = match.groups()
        return f"{year}-{month}-{day}"
    match = re.match(r"^(\d{4})-(\d{2})-(\d{2})$", date_str)
    if match:
        return date_str
    return date_str

def get_celex_from_url(url):
    m = re.search(r'CELEX:([0-9A-Z]+)', url, re.I)
    return m.group(1) if m else ""

def extract_dl_metadata(soup):
    metadata = {}
    multi_label_fields = {"Date of transposition"}
    for dl in soup.find_all("dl", class_="NMetadata"):
        dts = dl.find_all("dt")
        dds = dl.find_all("dd")
        for dt, dd in zip(dts, dds):
            label = dt.get_text(strip=True).replace(":", "")
            # Prefer human-readable <span> text if present
            spans = dd.find_all("span")
            if spans:
                value = ", ".join(span.get_text(strip=True) for span in spans)
            else:
                value = dd.get_text(" ", strip=True)
            value = value.split(";")[0].strip()
            if label in multi_label_fields:
                # Join all "Date of transposition" values
                if label in metadata:
                    if value not in metadata[label].split(", "):
                        metadata[label] += ", " + value
                else:
                    metadata[label] = value
            else:
                if label not in metadata:  # Only first occurrence
                    metadata[label] = value
    return metadata

# === 1. DOWNLOAD BOTH PAGES ===
celex = get_celex_from_url(eurlex_url)
nim_url = eurlex_url
all_url = eurlex_url.replace('/NIM/', '/ALL/')

headers = {'User-Agent': 'Mozilla/5.0'}

# Download NIM page (transposition)
nim_response = requests.get(nim_url, headers=headers)
nim_html = nim_response.text
nim_soup = BeautifulSoup(nim_html, "html.parser")

# Download ALL page (document metadata)
all_response = requests.get(all_url, headers=headers)
all_html = all_response.text
all_soup = BeautifulSoup(all_html, "html.parser")

# === 2. EXTRACT METADATA FROM ALL PAGE ===
all_metadata = extract_dl_metadata(all_soup)
print("Extracted document metadata:")
for k, v in all_metadata.items():
    print(f"  {k}: {v}")

# === 3. EXTRACT TRANSPOSTION MEASURES FROM NIM PAGE ===
eu_countries = {
    "AUT": "Austria", "BEL": "Belgium", "BGR": "Bulgaria", "HRV": "Croatia",
    "CYP": "Cyprus", "CZE": "Czechia", "DNK": "Denmark", "EST": "Estonia",
    "FIN": "Finland", "FRA": "France", "DEU": "Germany", "GRC": "Greece",
    "HUN": "Hungary", "IRL": "Ireland", "ITA": "Italy", "LVA": "Latvia",
    "LTU": "Lithuania", "LUX": "Luxembourg", "MLT": "Malta", "NLD": "Netherlands",
    "POL": "Poland", "PRT": "Portugal", "ROU": "Romania", "SVK": "Slovakia",
    "SVN": "Slovenia", "ESP": "Spain", "SWE": "Sweden"
}

data = []
li_list = nim_soup.find_all("li", class_=lambda x: x and x.endswith("_ntm"))
found_country_codes = set()
for li in li_list:
    li_classes = li.get("class")
    country_code = [c.split("_")[0] for c in li_classes if c.endswith("_ntm")][0]
    country_name = eu_countries.get(country_code, country_code)
    found_country_codes.add(country_code)

    # DEADLINE (try several locations)
    deadline = None
    search_node = li
    while search_node:
        prev = search_node.previous_sibling
        found = False
        while prev:
            if getattr(prev, "name", None) == "div" and "transposition" in prev.get("class", []):
                m = re.search(r"Transposition deadline[s]*:\s*([0-9/, ]+)", prev.get_text())
                if m:
                    deadline = m.group(1).strip()
                    found = True
                    break
            prev = prev.previous_sibling
        if found:
            break
        search_node = search_node.parent
        if getattr(search_node, "get", lambda x: None)("id") == country_code:
            break

    if not deadline:
        parent_panel = li.find_parent("div", class_="panel-collapse countryPanel")
        if parent_panel:
            deadline_div = parent_panel.find("div", id=f"{country_code}_transp")
            if deadline_div:
                m = re.search(r"Transposition deadline[s]*:\s*([0-9/, ]+)", deadline_div.get_text())
                if m:
                    deadline = m.group(1).split(",")[0].strip()
        if not deadline:
            row_div = nim_soup.find("div", class_="col-sm-12 ntmRow")
            if row_div:
                deadline_div = row_div.find("div", id=f"{country_code}_transposition")
                if deadline_div:
                    deadline = deadline_div.get_text(strip=True).split(",")[0].strip()

    title_tag = li.find("a", id="titleLink")
    measure_title = title_tag.text.strip() if title_tag else None

    publication_date = None
    pub_txt = li.get_text(" ", strip=True)
    m = re.search(r'Publication date:\s*([\d-]+)', pub_txt)
    if m:
        publication_date = standardize_date(m.group(1))
    else:
        for em in li.find_all("em"):
            if "Publication date" in em.parent.text:
                publication_date = standardize_date(em.text.strip())

    deadline_std = ""
    if deadline:
        deadlines = [standardize_date(x) for x in deadline.split(",")]
        deadline_std = ", ".join(deadlines)

    # Append measure row
    if measure_title:
        row = {
            "CELEX": celex,
            "Country Code": country_code,
            "Country": country_name,
            "Transposition Deadline": deadline_std,
            "Measure Title": measure_title,
            "Publication Date": publication_date,
            "Amending": ammend,

        }
        row.update(all_metadata)
        data.append(row)

# === 4. COUNTRIES WITH NO MEASURES ===
for code, name in eu_countries.items():
    if code not in found_country_codes:
        row = {
            "CELEX": celex,
            "Country Code": code,
            "Country": name,
            "Transposition Deadline": "",
            "Measure Title": "",
            "Publication Date": "",
            "Amending": ammend,

        }
        row.update(all_metadata)
        data.append(row)

# === 5. TO DATAFRAME/CSV ===
df = pd.DataFrame(data)
df.sort_values(by=["Country Code", "Transposition Deadline", "Measure Title"], inplace=True)

output_filename = f"transposition_{celex}.csv"
output_path = os.path.join(output_dir, output_filename)
df.to_csv(output_path, index=False)
print(f"Saved to {output_path}")
print(df.head(15))
# Out:
# Extracted document metadata:
#   Date of document: 27/10/2003
#   Date of effect: Entry into force, Date pub. See Art 31
#   Date of transposition: At the latest See Art 28.1
#   Date of end of validity: No end date
#   Author: Council of the European Union
#   Responsible body: Directorate-General for Taxation and Customs Union
#   Form: Directive
#   Addressee: The fifteen Member States: Belgium, Denmark, Germany, Ireland, Greece, Spain, France, Italy, Luxembourg, Netherlands, Austria, Portugal, Finland, Sweden, United Kingdom
#   Additional information: CNS 1997/0111, EEA relevance
#   Procedure number: 1997/0111/CNS
#   Link: European Parliament - Legislative observatory ​
#   Treaty: Treaty establishing the European Community
#   Legal basis: 12002E093
#   Proposal: 51997PC0030
#   Modifies: Relation Act Comment Subdivision concerned From To Repeal 31992L0081 Repeal 31992L0082
#   Modified by: Relation Act Comment Subdivision concerned From To Corrected by 32003L0096R(01) (ET) Corrected by 32003L0096R(02) (ET) Corrected by 32003L0096R(03) (HU) Corrected by 32003L0096R(04) (RO) Corrected by 32003L0096R(05) (LT) Corrected by 32003L0096R(06) (IT) Corrected by 32003L0096R(07) (HR) Corrected by 32003L0096R(08) (LT) Corrected by 32003L0096R(09) (IT) Corrected by 32003L0096R(10) (CS, FR, HR, LV, MT, RO, SL) Modified by 32004L0074 Amendment article 18.1 01/05/2004 Modified by 32004L0074 Amendment article 18.2 01/05/2004 Modified by 32004L0074 Addition annex 3 01/05/2004 Modified by 32004L0074 Addition article 18 BIS 01/05/2004 Modified by 32004L0075 Completion article 30 01/05/2004 Modified by 32004L0075 Addition article 18 TR 01/05/2004 Derogated in 12005SAN06/06 Derogation article 7 01/01/2007 Derogated in 12005SAN06/06 Derogation article 9 01/01/2007 Derogated in 12005SAN06/06 Derogation article 10 01/01/2007 Derogated in 12005SAN07/07 Derogation article 7 01/01/2007 Derogated in 12005SAN07/07 Derogation article 9 01/01/2007 Derogated in 12005SAN07/07 Derogation article 10 01/01/2007 Derogated in 12005SPN06/06 Derogation article 10 01/01/2007 Derogated in 12005SPN06/06 Derogation article 7 01/01/2007 Derogated in 12005SPN06/06 Derogation article 9 01/01/2007 Derogated in 12005SPN07/07 Derogation article 10 01/01/2007 Derogated in 12005SPN07/07 Derogation article 7 01/01/2007 Derogated in 12005SPN07/07 Derogation article 9 01/01/2007 Modified by 32018D0552 Replacement annex I TABL C Text 15/09/2018 Modified by 32018D0552 Replacement article 16 paragraph 1 L 2 Text 15/09/2018 Modified by 32018D0552 Replacement article 20 paragraph 1 point (c) FR 2 TEXT 15/09/2018 Modified by 32018D0552 Replacement article 20 paragraph 1 point (c) FR 1 TEXT 15/09/2018 Modified by 32018D0552 Replacement annex I TABL B Text 15/09/2018 Modified by 32018D0552 Replacement article 20 paragraph 1 point (h) TEXT 15/09/2018 Modified by 32018D0552 Replacement article 2 paragraph 1 point (h) TEXT 15/09/2018 Modified by 32018D0552 Replacement annex I TABL A Text 15/09/2018 Modified by 32018D0552 Replacement article 16 paragraph 1 L 1 indent 2 TEXT 15/09/2018 Modified by 32022D2521 Replacement (RO) article 16 paragraph 1 indent 2 10/01/2023 Modified by 32022D2521 Replacement (RO) article 2 paragraph 1 point (h) 10/01/2023 Modified by 32022D2521 Replacement (RO) article 20 paragraph 1 point (h) 10/01/2023
 3 Preliminary question submitted by 62015CN0465 A14P1LC Interpreted by 62016CJ0151 A01 Interpreted by 62016CJ0215 A02P1 Interpreted by 62016CJ0215 A02P2 Interpreted by 62016CJ0215 A04 Interpreted by 62016CJ0215 article 14 paragraph 1 point (c) Preliminary question submitted by 62016CN0151 article 4 Preliminary question submitted by 62016CN0215 article 4 Preliminary question submitted by 62016CN0216 article 4 Preliminary question submitted by 62016CN0220 article 4 Preliminary question submitted by 62016CN0221 A15P1LC Interpreted by 62017CJ0031 A21P3 Interpreted by 62017CJ0049 A14P1LA Interpreted by 62017CJ0090 A21P5L3 Interpreted by 62017CJ0090 A18P10L2 Interpreted by 62017CJ0103 article 14 paragraph 1 point (a) Preliminary question submitted by 62017CN0031 article 15 paragraph 1 point (c) Preliminary question submitted by 62017CN0031 article 21 paragraph 3 Preliminary question submitted by 62017CN0049 article 21 paragraph 5 Preliminary question submitted by 62017CN0090 article 21 paragraph 5 L 1 Preliminary question submitted by 62017CN0090 article 21 paragraph 5 L 3 Preliminary question submitted by 62017CN0090 Preliminary question submitted by 62017CN0103 article 18 paragraph 10 L 2 Preliminary question submitted by 6201 ...
#   Instruments cited: 12002000000 12002E006 12002E087 12002E088 21994A0207(02) 22002A0515(01) 31970L0156 31983L0189 31990R3037 31992L0012 31992L0083 31999D0468 32001R2031
#   EUROVOC descriptor: tax system, energy-generating product, electrical energy
#   Subject matter: Internal market - Principles, Protocol on Ireland/Northern Ireland, Annex 3 Provisions of Union law referred to in Article 8, Excise, Taxation, Approximation of laws
#   Directory code: Taxation, Indirect taxation, Excise duties
# Saved to /Users/nicolomarchini/Documents/Università/Magistrale/Tesi Magistrale/Directives/transposition_32003L0096.csv
#          CELEX Country Code   Country Transposition Deadline  \
# 84  32003L0096          AUT   Austria             1001-01-01
# 0   32003L0096          BEL   Belgium             1001-01-01
# 1   32003L0096          BEL   Belgium             1001-01-01
# 2   32003L0096          BEL   Belgium             1001-01-01
# 3   32003L0096          BGR  Bulgaria             1001-01-01
# 63  32003L0096          CYP    Cyprus             1001-01-01
# 62  32003L0096          CYP    Cyprus             1001-01-01
# 64  32003L0096          CYP    Cyprus             2004-05-01
# 4   32003L0096          CZE   Czechia             1001-01-01
# 5   32003L0096          CZE   Czechia             1001-01-01
# 27  32003L0096          CZE   Czechia             2004-05-01
# 22  32003L0096          CZE   Czechia             2004-05-01
# 32  32003L0096          CZE   Czechia             2004-05-01
# 23  32003L0096          CZE   Czechia             2004-05-01
# 33  32003L0096          CZE   Czechia             2004-05-01
#
#                                         Measure Title Publication Date  \
# 84  Bundesgesetz, mit dem die Mineralölsteuer an d...       2003-08-20
# 0   Arrêté royal du 29/2/2004 portant dispositions...       2004-03-05
# 1   Arrêté royaldu 29/2/2004 modifiant la loi du 2...       2004-03-05
# 2   Articles 414 à 442 de la Loi-programme du 27/1...       2004-12-31
# 3              Закон за акцизите и данъчните складове       2006-12-22
# 63  Ο Περί Φόρων Κατανάλωσης (Τροποποιητικός) Νόμο...       2006-04-14
# 62            Ο Περί Φόρων Κατανάλωσης Νόμος του 2004       2004-04-30
# 64  Ο Περί Φόρων Κατανάλωσης (Τροποποιητικός) (Αρ....       2010-06-17
# 4   Zákon č. 313/2004 Sb., o státním dluhopisovém ...       2004-05-27
# 5   Zákon č. 453/2016 Sb., kterým se mění zákon č....       2016-12-29
# 27  Vyhláška č. 79/2019 Sb., o způsobu výpočtu výš...       2019-03-21
# 22  Zákon č. 131/2015 Sb., kterým se mění zákon č....       2015-06-05
# 32  Zákon č. 131/2022 Sb., kterým se mění zákon č....       2022-05-27
# 23  Zákon č. 157/2015 Sb., kterým se mění zákon č....       2015-06-29
# 33  Zákon č. 179/2022 Sb., kterým se mění zákon č....       2022-06-27
#
#     Amending Date of document                          Date of effect  \
# 84     False       27/10/2003  Entry into force, Date pub. See Art 31
# 0      False       27/10/2003  Entry into force, Date pub. See Art 31
# 1      False       27/10/2003  Entry into force, Date pub. See Art 31
# 2      False       27/10/2003  Entry into force, Date pub. See Art 31
# 3      False       27/10/2003  Entry into force, Date pub. See Art 31
# 63     False       27/10/2003  Entry into force, Date pub. See Art 31
# 62     False       27/10/2003  Entry into force, Date pub. See Art 31
# 64     False       27/10/2003  Entry into force, Date pub. See Art 31
# 4      False       27/10/2003  Entry into force, Date pub. See Art 31
# 5      False       27/10/2003  Entry into force, Date pub. See Art 31
# 27     False       27/10/2003  Entry into force, Date pub. See Art 31
# 22     False       27/10/2003  Entry into force, Date pub. See Art 31
# 32     False       27/10/2003  Entry into force, Date pub. See Art 31
# 23     False       27/10/2003  Entry into force, Date pub. See Art 31
# 33     False       27/10/2003  Entry into force, Date pub. See Art 31
#
#          Date of transposition  ... Legal basis     Proposal  \
# 84  At the latest See Art 28.1  ...   12002E093  51997PC0030
# 0   At the latest See Art 28.1  ...   12002E093  51997PC0030
# 1   At the latest See Art 28.1  ...   12002E093  51997PC0030
# 2   At the latest See Art 28.1  ...   12002E093  51997PC0030
# 3   At the latest See Art 28.1  ...   12002E093  51997PC0030
# 63  At the latest See Art 28.1  ...   12002E093  51997PC0030
# 62  At the latest See Art 28.1  ...   12002E093  51997PC0030
# 64  At the latest See Art 28.1  ...   12002E093  51997PC0030
# 4   At the latest See Art 28.1  ...   12002E093  51997PC0030
# 5   At the latest See Art 28.1  ...   12002E093  51997PC0030
# 27  At the latest See Art 28.1  ...   12002E093  51997PC0030
# 22  At the latest See Art 28.1  ...   12002E093  51997PC0030
# 32  At the latest See Art 28.1  ...   12002E093  51997PC0030
# 23  At the latest See Art 28.1  ...   12002E093  51997PC0030
# 33  At the latest See Art 28.1  ...   12002E093  51997PC0030
#
#                                              Modifies  \
# 84  Relation Act Comment Subdivision concerned Fro...
# 0   Relation Act Comment Subdivision concerned Fro...
#                                     Instruments cited  \
# 84  12002000000 12002E006 12002E087 12002E088 2199...
# 0   12002000000 12002E006 12002E087 12002E088 2199...
# 1   12002000000 12002E006 12002E087 12002E088 2199...
# 2   12002000000 12002E006 12002E087 12002E088 2199...
# 3   12002000000 12002E006 12002E087 12002E088 2199...
# 63  12002000000 12002E006 12002E087 12002E088 2199...
# 62  12002000000 12002E006 12002E087 12002E088 2199...
# 64  12002000000 12002E006 12002E087 12002E088 2199...
# 4   12002000000 12002E006 12002E087 12002E088 2199...
# 5   12002000000 12002E006 12002E087 12002E088 2199...
# 27  12002000000 12002E006 12002E087 12002E088 2199...
# 22  12002000000 12002E006 12002E087 12002E088 2199...
# 32  12002000000 12002E006 12002E087 12002E088 2199...
# 23  12002000000 12002E006 12002E087 12002E088 2199...
# 33  12002000000 12002E006 12002E087 12002E088 2199...
#
#                                    EUROVOC descriptor  \
# 84  tax system, energy-generating product, electri...
# 0   tax system, energy-generating product, electri...
# 1   tax system, energy-generating product, electri...
# 2   tax system, energy-generating product, electri...
# 3   tax system, energy-generating product, electri...
# 63  tax system, energy-generating product, electri...
# 62  tax system, energy-generating product, electri...
# 64  tax system, energy-generating product, electri...
# 4   tax system, energy-generating product, electri...
# 5   tax system, energy-generating product, electri...
# 27  tax system, energy-generating product, electri...
# 22  tax system, energy-generating product, electri...
# 32  tax system, energy-generating product, electri...
# 23  tax system, energy-generating product, electri...
# 33  tax system, energy-generating product, electri...
#
#                                        Subject matter  \
# 84  Internal market - Principles, Protocol on Irel...
# 0   Internal market - Principles, Protocol on Irel...
# 1   Internal market - Principles, Protocol on Irel...
# 2   Internal market - Principles, Protocol on Irel...
# 3   Internal market - Principles, Protocol on Irel...
# 63  Internal market - Principles, Protocol on Irel...
# 62  Internal market - Principles, Protocol on Irel...
# 64  Internal market - Principles, Protocol on Irel...
# 4   Internal market - Principles, Protocol on Irel...
# 5   Internal market - Principles, Protocol on Irel...
# 27  Internal market - Principles, Protocol on Irel...
# 22  Internal market - Principles, Protocol on Irel...
# 32  Internal market - Principles, Protocol on Irel...
# 23  Internal market - Principles, Protocol on Irel...
# 33  Internal market - Principles, Protocol on Irel...
#
#                                 Directory code
# 84  Taxation, Indirect taxation, Excise duties
# 0   Taxation, Indirect taxation, Excise duties
# 1   Taxation, Indirect taxation, Excise duties
# 2   Taxation, Indirect taxation, Excise duties
# 3   Taxation, Indirect taxation, Excise duties
# 63  Taxation, Indirect taxation, Excise duties
# 62  Taxation, Indirect taxation, Excise duties
# 64  Taxation, Indirect taxation, Excise duties
# 4   Taxation, Indirect taxation, Excise duties
# 5   Taxation, Indirect taxation, Excise duties
# 27  Taxation, Indirect taxation, Excise duties
# 22  Taxation, Indirect taxation, Excise duties
# 32  Taxation, Indirect taxation, Excise duties
# 23  Taxation, Indirect taxation, Excise duties
# 33  Taxation, Indirect taxation, Excise duties
#
# [15 rows x 29 columns]
